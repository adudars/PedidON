# %% [markdown]
# <a href="https://colab.research.google.com/github/adudars/PedidON/blob/master/arquivos/9.1_ConsultasTabelas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 9.1 CONSULTAS DAS TABELAS COM TODOS OS DADOS INSERIDOS

# %% [markdown]
# ## ESTABELECENDO CONEXÃO

# %% [markdown]
# ### Instalando bibliotecas de acesso

# %%
#!pip install --user psycopg2-binary
#!pip install --user pandas

# %% [markdown]
# ### Importando bibliotecas

# %%
import pandas as pd
import psycopg2
# Out:
# /usr/local/lib/python3.6/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %% [markdown]
# ### Conectando com o banco através do psycopg2

# %%
conn = psycopg2.connect(host="lallah.db.elephantsql.com",database="nxthbnlu", user="nxthbnlu", password="buyAYKsY17pqexg1grIcJaWm0gHBsO2F")

# %% [markdown]
# ## SELECT SIMPLES DAS TABELAS

# %% [markdown]
# ### Tabela cliente

# %%
cliente = pd.read_sql_query("select * from cliente", conn)

# %%
cliente
# Out:
#     id_cliente  nome_cliente  cpf_cliente
# 0            1          Lara        10582
# 1            2         Jorge        11736
# 2            3         Clara        12890
# 3            4          Davi        14045
# 4            5        Milton        15199
# 5            6         Luiza        18662
# 6            7           Ana        16354
# 7            8          Tais        17508
# 8            9      Isabella        19817
# 9           10      Henrique        22010
# 10          11       Clarice        25648
# 11          12         Bento        34862
# 12          13         Diego        56412
# 13          14         Mauro        15649
# 14          15     Antonella        26456
# 15          26  José Geraldo        11111
# 16          27       Eduarda        22222
# 17          28     Gabrielle        33333
# 18          29        Thiago        44444
# 19          30        Moises        55555

# %% [markdown]
# ### Tabela funcionário

# %%
funcionario = pd.read_sql_query("select * from funcionario", conn)

# %%
funcionario
# Out:
#     id_funcionario nome_funcionario  matricula_funcionario
# 0                1         Bernardo                2210921
# 1                2          Matheus                3874638
# 2                3           Ismael                4733307
# 3                4         Fernanda                1321541
# 4                5           Martin                2241335
# 5                6          Gabriel                1124365
# 6                7            Aline                2214289
# 7                8            Maria                3298845
# 8                9           Eloisa                1139887
# 9               10        Ana Clara                4423569
# 10              11          Juliana                6565279
# 11              12           Adrian                2325499
# 12              13          Ronaldo                9999999
# 13              14   Roberto Carlos                6666666
# 14              15           Marcos                1111111
# 15              16          Rivaldo                1010101
# 16              17             Cafu                2222222
# 17              18            Lucio                3333333
# 18              19     Roque Junior                4444444
# 19              20         Edmilson                5555555

# %% [markdown]
# ### Tabela comanda

# %%
comanda = pd.read_sql_query("select * from comanda", conn)

# %%
comanda
# Out:
#     id_comanda  mesa        data  fk_id_cliente  fk_id_funcionario
# 0            1    13  2020-07-30              1                  1
# 1            2     1  2020-07-30              2                  1
# 2            3     4  2020-07-30              3                  2
# 3            4    12  2020-07-30              4                  3
# 4            5     3  2020-07-30              5                  2
# 5            6     1  2020-07-31              2                  3
# 6            7    13  2020-07-31              6                  1
# 7            8     2  2020-07-31              7                  2
# 8            9    12  2020-07-31              8                  3
# 9           10     4  2020-08-01              4                  1
# 10          11    13  2020-08-01              2                  2
# 11          12    12  2020-08-01              9                  3
# 12          13    13  2020-08-01             10                  2
# 13          14     1  2020-08-02             11                  1
# 14          15     2  2020-08-02             12                  2
# 15          16     3  2020-08-02             13                  3
# 16          17     4  2020-08-02             14                  4
# 17          18     5  2020-08-02             15                  5
# 18          19     6  2020-08-02              1                  6
# 19          20     7  2020-08-02              2                  7
# 20          21     8  2020-08-02              3                  8
# 21          22     9  2020-08-02              4                  9
# 22          23    10  2020-08-02              5                 10
# 23          24    11  2020-08-03              6                 11
# 24          25    12  2020-08-03              7                 12
# 25          26    13  2020-08-03              8                  1
# 26          27     1  2020-08-03              9                  2
# 27          28     2  2020-08-03             10                  3
# 28          29     3  2020-08-03             11                  4
# 29          30     4  2020-08-03             12                  5
# 30          31     5  2020-08-03             13                  6
# 31          32     6  2020-08-03             14                  7
# 32          33     7  2020-08-03             15                  8
# 33          34     8  2020-08-03              1                  9
# 34          35     9  2020-08-03              2                 10
# 35          36    10  2020-08-04              3                 11
# 36          37    11  2020-08-04              4                 12
# 37          38    12  2020-08-04              5                  1
# 38          39    13  2020-08-04              6                  2
# 39          40     1  2020-08-04              7                  3
# 40          41     2  2020-08-04              8                  4
# 41          42     3  2020-08-04              9                  5
# 42          43     4  2020-08-04             10                  6
# 43          44     5  2020-08-04             11                  7
# 44          45     6  2020-08-04             12                  8
# 45          46     7  2020-08-04             13                  9
# 46          47     8  2020-08-04             14                 10
# 47          48     9  2020-08-04             15                 11
# 48          49    10  2020-08-04              1                 12
# 49          50    11  2020-08-04              2                  1
# 50          61     1  2020-08-03             26                 13
# 51          62     2  2020-08-03             27                 14
# 52          63     3  2020-08-03             28                 15
# 53          64     4  2020-08-03             29                 16
# 54          65     5  2020-08-03             30                 17
# 55          66     6  2020-08-04             26                 18
# 56          67     7  2020-08-04             27                 19
# 57          68     8  2020-08-04             28                 20
# 58          69     9  2020-08-04             29                  1
# 59          70    10  2020-08-04             30                  2

# %% [markdown]
# ### Tabela pedido

# %%
pedido = pd.read_sql_query("select * from pedido", conn)

# %%
pedido
# Out:
#     id_pedido  quantidade      hora  fk_id_comanda  fk_id_itemcardapio
# 0           1           2  12:58:00              1                   1
# 1           2           1  13:19:00              1                   2
# 2           3           1  12:34:00              2                   3
# 3           4           3  12:45:00              3                   4
# 4           5           1  12:45:00              3                   5
# ..        ...         ...       ...            ...                 ...
# 67         68           1  12:43:00             66                  13
# 68         69           2  13:09:00             67                  14
# 69         70           3  13:38:00             68                  15
# 70         71           4  13:51:00             69                  16
# 71         72           2  14:00:00             70                  17
#
# [72 rows x 5 columns]

# %% [markdown]
# ### Tabela item cardápio

# %%
cardapio = pd.read_sql_query("select * from item_cardapio", conn)

# %%
cardapio
# Out:
#     id_itemcardapio              nome_item  ...  fk_id_categoria fk_id_tamanho
# 0                 1          Reta da Penha  ...                1             2
# 1                 2               Rua Sete  ...                1             2
# 2                 3         Parque Moscoso  ...                3             1
# 3                 4      Convento da Penha  ...                3             1
# 4                 5           Ilha de Socó  ...                4             2
# 5                 8          Stella Artois  ...                8             4
# 6                 9                  Pepsi  ...               17             5
# 7                11              Beira mar  ...               15            20
# 8                12                Caiaque  ...               19             2
# 9                13                 Arrais  ...                7             2
# 10               14                  Brisa  ...                6             2
# 11               15                Cachaça  ...               16            18
# 12               16                  Appia  ...                8            14
# 13               17              Red Label  ...                9            19
# 14               18                  Ciroc  ...               10            17
# 15               19    Taqueray Experience  ...               11            19
# 16               20          Borgo Magredo  ...                5            11
# 17               21              Semblante  ...               12            10
# 18               22        Chandon Passion  ...               13            11
# 19               23       Palácio Anchieta  ...                3             7
# 20               24             Paneleiras  ...                3             6
# 21               25          Gruta da onça  ...                3             3
# 22               26                   Suco  ...               18             8
# 23               27                   Suco  ...               18             9
# 24               29               Red Bull  ...               14             5
# 25               30               Alto mar  ...               14            12
# 26               31         Capitão Sharky  ...               14            13
# 27               32                 Mojito  ...                2            15
# 28               33              Coca cola  ...               17            16
# 29               34   Viejo Rincon Reserva  ...               12            10
# 30               35  Chungara Gran Reserva  ...                5            10
# 31               36         Veuve Clicquot  ...               13            11
# 32               37                Absolut  ...               10            15
# 33               38                Campari  ...               16            18
# 34               39           Jack Daniels  ...                9            18
# 35               40               Colorado  ...                8            14
# 36               41                   Água  ...               20            12
# 37               42         Beffeater pink  ...               11            19
# 38               43          Ilha do Frade  ...                4             1
# 39               44                Maresia  ...                6             2
# 40               45                 Marujo  ...                7             2
# 41               46             Marinheiro  ...                7             2
# 42               47           Pituã Island  ...                2            13
# 43               48          Brasil Brasil  ...                2            16
# 44               49                 Corona  ...                8             4
# 45               50                 Brahma  ...                8             4
# 46               28                   Água  ...               20            12
# 47                6  Bons ventos te trazem  ...                2            12
# 48                7             Barlavento  ...                2            12
# 49               10             Cidade Sol  ...                2            12
#
# [50 rows x 6 columns]

# %% [markdown]
# ### Tabela observação

# %%
obs = pd.read_sql_query("select * from observacao", conn)

# %%
obs
# Out:
#     id_obs                                      descricao_obs  fk_id_pedido
# 0        1                                            Sem sal             1
# 1        2                            Um prato e talher extra             4
# 2        3                                          Sem nozes             5
# 3        4                                         Sem espuma             7
# 4        5                        Dois copos com gelo e limão             9
# 5        6                                Sem os pães da casa            12
# 6        7                                       Sem maracujá            10
# 7        8                                     Servir no copo             8
# 8       10                                  Adicionar pimenta            11
# 9        9                              Porção extra de arroz            14
# 10      11                                     Só filé mignon            27
# 11      12                                      Copo com gelo            30
# 12      13                                  Azeitonas no copo            35
# 13      14                                   Legumes no ponto            40
# 14      15                                           Limonada            41
# 15      16                               Abrir na minha frete            50
# 16      17                                 Água de coco junto            54
# 17      18                                       Coloca limão            55
# 18      19  Ostras de Vitória mesmo. De Santa Catarina vai...            66
# 19      20                                    2 águas de coco            72

# %% [markdown]
# ### Tabela categoria

# %%
categoria = pd.read_sql_query("select * from categoria", conn)

# %%
categoria
# Out:
#     id_categoria nome_categoria
# 0              1        entrada
# 1              2          drink
# 2              3      principal
# 3              4      sobremesa
# 4              5   vinho branco
# 5              6      sanduiche
# 6              7       crepioca
# 7              8        cerveja
# 8              9         whisky
# 9             10          vodka
# 10            11            gin
# 11            12    vinho tinto
# 12            13      espumante
# 13            14      softdrink
# 14            15        petisco
# 15            17   refrigerante
# 16            18           suco
# 17            19       infantil
# 18            20         bebida
# 19            16        cachaça

# %% [markdown]
# ### Tabela tamanho

# %%
tamanho = pd.read_sql_query("select * from tamanho", conn)

# %%
tamanho
# Out:
#     id_tamanho descricao_tamanho
# 0            1         2 pessoas
# 1            4         long neck
# 2            5              lata
# 3            2          1 pessoa
# 4            3         3 pessoas
# 5            6         4 pessoas
# 6            7         5 pessoas
# 7            8             jarra
# 8            9              copo
# 9           10              taça
# 10          11           garrafa
# 11          12             330ml
# 12          13             500ml
# 13          14             600ml
# 14          15                1l
# 15          16                2l
# 16          17                3l
# 17          18              dose
# 18          19             combo
# 19          20           unidade
